# %%
import numpy as np
import pandas as pd
import networkx as nx

# %%
path = "./scrape_results_astrophotography.csv"
data = pd.read_csv(path)

# %%
data
# Out:
#          searched_for            user_name  \
# 0   #astrophotography         chabiarleiva
# 1   #astrophotography            bosplanet
# 2   #astrophotography        danilo7chacon
# 3   #astrophotography       denyabdurahman
# 4   #astrophotography           sp4ce_n3rd
# 5   #astrophotography  astronaut_from_mars
# 6   #astrophotography         angello_gonz
# 7   #astrophotography     frenchskywatcher
# 8   #astrophotography         mandragorayp
# 9   #astrophotography       astro_parallax
# 10  #astrophotography     seestar.official
# 11  #astrophotography           kaan.astro
# 12  #astrophotography        mihailvminkov
# 13  #astrophotography       dudelovesspace
# 14  #astrophotography           astrogeekz
#
#                                         post_hashtags  likes_count  \
# 0   ['#cosmos', '#astrophotography', '#estrellas',...         4900
# 1   ['#Saturn', '#Jupiter', '#AndromedaGalaxy', '#...       814900
# ...
